# %%
import matplotlib.pyplot as plt

# %%
import re

# %%
def plot(str):
    train_losses = [float(val) for val in re.findall(r"train_loss:\s*([\d\.]+)", str)]
    val_losses = [float(val) for val in re.findall(r"val_loss:\s*([\d\.]+)", str)]
    print(len(val_losses))
    print(val_losses)
    steps = [i*200 for i in range(len(val_losses))]

    plt.plot(steps, train_losses, label='Train Loss')
    plt.plot(steps, val_losses, label='Val Loss')
    plt.xlabel('Steps')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)

# %%
turkce_cocuk_kelimeleri = {
    "aile_ve_akraba": [
        "anne", "baba", "kardeş", "dede", "anneanne", "babaanne", "amca", "hala", 
        "dayı", "teyze", "abla", "ağabey", "nine", "torun", "bebek", "çocuk"
    ],
    "vucudumuz": [
        "el", "ayak", "baş", "göz", "kulak", "burun", "ağız", "diş", "saç", "kol", 
        "parmak", "diz", "omuz", "dil", "boyun", "karın", "sırt", "yüz", "kaş", "kirpik"
    ],
    "ev_ve_esya": [
        "ev", "oda", "kapı", "pencere", "masa", "sandalye", "yatak", "dolap", "halı", 
        "perde", "ayna", "saat", "lamba", "televizyon", "bilgisayar", "telefon", 
        "bardak", "tabak", "kaşık", "çatal", "bıçak", "tava", "tencere", "buzdolabı"
    ],
    "yiyecek_ve_icecek": [
        "su", "süt", "ekmek", "yemek", "elma", "muz", "çilek", "portakal", "havuç", 
        "patates", "domates", "yumurta", "peynir", "zeytin", "bal", "şeker", "tuz", 
        "çorba", "pilav", "makarna", "et", "balık", "yoğurt"
    ],
    "hayvanlar": [
        "kedi", "köpek", "kuş", "balık", "at", "inek", "koyun", "tavuk", "horoz", 
        "ördek", "tavşan", "aslan", "fil", "zürafa", "maymun", "yılan", "kaplumbağa", 
        "arı", "kelebek", "karınca"
    ],
    "giysiler": [
        "pantolon", "tişört", "kazak", "ceket", "mont", "ayakkabı", "çorap", 
        "şapka", "eldiven", "atkı", "pijama", "etek", "elbise", "gömlek"
    ],
    "tasitlar": [
        "araba", "otobüs", "kamyon", "uçak", "gemi", "tren", "bisiklet", 
        "motosiklet", "traktör", "vapur", "helikopter"
    ],
    "renkler": [
        "kırmızı", "mavi", "sarı", "yeşil", "beyaz", "siyah", "turuncu", 
        "mor", "pembe", "kahverengi", "gri"
    ],
    "dogave_hava": [
        "güneş", "ay", "yıldız", "bulut", "yağmur", "kar", "rüzgar", "deniz", 
        "dağ", "orman", "ağaç", "çiçek", "toprak", "taş", "kum", "gökyüzü"
    ],
    "fiiller_eylemler": [
        "almak", "vermek", "gelmek", "gitmek", "bakmak", "görmek", "yemek", 
        "içmek", "uyumak", "oynamak", "koşmak", "oturmak", "kalkmak", "gülmek", 
        "ağlamak", "okumak", "yazmak", "sevmek", "korkmak", "durmak", "yapmak"
    ],
    "sifatlar": [
        "büyük", "küçük", "uzun", "kısa", "güzel", "çirkin", "iyi", "kötü", 
        "sıcak", "soğuk", "yeni", "eski", "temiz", "kirli", "mutlu", "üzgün"
    ],
    "sayilar": [
        "bir", "iki", "üç", "dört", "beş", "altı", "yedi", "sekiz", "dokuz", "on"
    ],
    "zaman_kavramlari": [
        "gün", "gece", "sabah", "öğle", "akşam", "dün", "bugün", "yarın", 
        "şimdi", "sonra", "önce"
    ]
}
